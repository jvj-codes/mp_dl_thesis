# %%
# -*- coding: utf-8 -*-

"""
Created on Tue Feb 11 09:25:53 2025

@author: JVJ
"""

#%load_ext autoreload
#%autoreload 2

from WealthChannelsModel import WealthBehaviorModelClass
import numpy as np
import sympy
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
plt.rcParams.update({
    "axes.grid": True,
    "grid.color": "black",
    "grid.alpha": 0.25,
    "grid.linestyle": "--",
    "font.size": 14                    # Set font size
})
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
from EconDLSolvers import choose_gpu
import torch, gc
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

torch.cuda.empty_cache()

# Hyperparameters
device = choose_gpu()
model_DL = {}

# DeepSimulate
K_time = 2.0
model_DL['DeepSimulateBetaHigh'] = WealthBehaviorModelClass(algoname='DeepSimulate', par={'beta': 0.99},device=device,train={'K_time': K_time})
model_DL['DeepSimulateBetaHigh'].solve(do_print=True)

model_DL['DeepSimulateBetaLow'] = WealthBehaviorModelClass(algoname='DeepSimulate',par={'beta': 0.95}, device=device,train={'K_time': K_time})
model_DL['DeepSimulateBetaLow'].solve(do_print=True)

#model_DL['DeepSimulate'].save('DeepSimulate_30M_target_inflation.pkl')

# DeepVPD
#K_time = 30.0
#model_DL['DeepVPD'] = WealthBehaviorModelClass(algoname='DeepVPD', device=device,train={'K_time': K_time})
#model_DL['DeepVPD'].solve(do_print=True)

#model_DL['DeepVPD'].save('DeepVPD_30M_target_inflation.pkl')

#K_time = 5.0
#model_DL['DeepFOC'] = WealthBehaviorModelClass(algoname='DeepFOC',par={'KKT': True}, device=device,train={'K_time': K_time})
#model_DL['DeepFOC'].solve(do_print=True)

#model_DL['DeepVPD'].save('DeepFOC_5M_target_inflation.pkl')
# Out:
# GPU 0: 79.19GB free
# Best GPU: 0
# started solving: 2025-04-02 09:11:08
# k =     0 of inf: sim.R = -2568215808.00000000 [best: -2568215808.00000000] [1.0 secs] [value_epochs =  11] [policy_epochs =   0] [  0.02 mins]
# k =    10 of inf: sim.R = -2568215808.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  11] [policy_epochs =   0] [  0.10 mins] no improvements in 0.1 mins
# k =    20 of inf: sim.R = -2568215808.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  11] [policy_epochs =   0] [  0.18 mins] no improvements in 0.2 mins
# k =    30 of inf: sim.R = -2568215808.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  11] [policy_epochs =   0] [  0.27 mins] no improvements in 0.3 mins
# k =    40 of inf: sim.R = -2568215808.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  11] [policy_epochs =   0] [  0.35 mins] no improvements in 0.3 mins
# k =    50 of inf: sim.R = -2659729152.00000000 [best: -2568215808.00000000] [0.7 secs] [value_epochs =  11] [policy_epochs =  15] [  0.44 mins] no improvements in 0.4 mins
# k =    60 of inf: sim.R = -3250441728.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  11] [policy_epochs =  15] [  0.53 mins] no improvements in 0.5 mins
# k =    70 of inf: sim.R = -3318219008.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  11] [policy_epochs =  15] [  0.63 mins] no improvements in 0.6 mins
# k =    80 of inf: sim.R = -3228994048.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  11] [policy_epochs =  15] [  0.73 mins] no improvements in 0.7 mins
# k =    90 of inf: sim.R = -3016010752.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  11] [policy_epochs =  15] [  0.82 mins] no improvements in 0.8 mins
# k =   100 of inf: sim.R = -2934497024.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  11] [policy_epochs =   6] [  0.91 mins] no improvements in 0.9 mins
# k =   110 of inf: sim.R = -2848267776.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  14] [policy_epochs =  13] [  1.00 mins] no improvements in 1.0 mins
# k =   120 of inf: sim.R = -2770647552.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  14] [policy_epochs =   6] [  1.09 mins] no improvements in 1.1 mins
# k =   130 of inf: sim.R = -2675688960.00000000 [best: -2568215808.00000000] [0.6 secs] [value_epochs =  18] [policy_epochs =   6] [  1.18 mins] no improvements in 1.2 mins
# k =   140 of inf: sim.R = -2533107712.00000000 [best: -2533107712.00000000] [0.6 secs] [value_epochs =  13] [policy_epochs =   6] [  1.27 mins]
# k =   150 of inf: sim.R = -2316286208.00000000 [best: -2316286208.00000000] [0.6 secs] [value_epochs =  50] [policy_epochs =   6] [  1.37 mins]
# k =   160 of inf: sim.R = -811870080.00000000 [best: -811870080.00000000] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  1.47 mins]
# k =   170 of inf: sim.R = -75.72987366 [best: -75.72987366] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  1.57 mins]
# k =   180 of inf: sim.R = -75.28561401 [best: -75.28561401] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  1.68 mins]
# k =   190 of inf: sim.R = -75.94952393 [best: -75.28561401] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  1.79 mins] no improvements in 0.1 mins
# k =   200 of inf: sim.R = -76.05735016 [best: -75.28561401] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  1.90 mins] no improvements in 0.2 mins
# k =   210 of inf: sim.R = -76.03127289 [best: -75.28561401] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  2.00 mins] no improvements in 0.3 mins
# k =   220 of inf: sim.R = -75.51305389 [best: -75.28561401] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  2.11 mins] no improvements in 0.4 mins
# k =   230 of inf: sim.R = -74.14234161 [best: -74.14234161] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  2.22 mins]
# k =   240 of inf: sim.R = -71.55213165 [best: -71.55213165] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  2.33 mins]
# k =   250 of inf: sim.R = -70.55063629 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  2.44 mins]
# k =   260 of inf: sim.R = -81.74388885 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  2.54 mins] no improvements in 0.1 mins
# k =   270 of inf: sim.R = -108.33801270 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  2.65 mins] no improvements in 0.2 mins
# k =   280 of inf: sim.R = -131.88824463 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  2.76 mins] no improvements in 0.3 mins
# k =   290 of inf: sim.R = -144.72232056 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  2.87 mins] no improvements in 0.4 mins
# k =   300 of inf: sim.R = -150.79281616 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  2.98 mins] no improvements in 0.5 mins
# k =   310 of inf: sim.R = -153.55717468 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  3.08 mins] no improvements in 0.6 mins
# k =   320 of inf: sim.R = -154.80213928 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  3.19 mins] no improvements in 0.8 mins
# k =   330 of inf: sim.R = -155.31909180 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  3.30 mins] no improvements in 0.9 mins
# k =   340 of inf: sim.R = -155.47889709 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  11] [  3.41 mins] no improvements in 1.0 mins
# k =   350 of inf: sim.R = -155.47337341 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  11] [  3.51 mins] no improvements in 1.1 mins
# k =   360 of inf: sim.R = -155.46655273 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  15] [  3.61 mins] no improvements in 1.2 mins
# k =   370 of inf: sim.R = -155.42198181 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  11] [  3.72 mins] no improvements in 1.3 mins
# k =   380 of inf: sim.R = -155.43704224 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   7] [  3.82 mins] no improvements in 1.4 mins
# k =   390 of inf: sim.R = -155.47549438 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  10] [  3.92 mins] no improvements in 1.5 mins
# k =   400 of inf: sim.R = -155.46347046 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  10] [  4.02 mins] no improvements in 1.6 mins
# k =   410 of inf: sim.R = -155.50598145 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  4.12 mins] no improvements in 1.7 mins
# k =   420 of inf: sim.R = -155.51136780 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  4.22 mins] no improvements in 1.8 mins
# k =   430 of inf: sim.R = -155.49302673 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  4.33 mins] no improvements in 1.9 mins
# k =   440 of inf: sim.R = -155.54153442 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  13] [  4.43 mins] no improvements in 2.0 mins
# k =   450 of inf: sim.R = -155.57914734 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  4.53 mins] no improvements in 2.1 mins
# k =   460 of inf: sim.R = -155.60293579 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   7] [  4.63 mins] no improvements in 2.2 mins
# k =   470 of inf: sim.R = -155.60382080 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  11] [  4.73 mins] no improvements in 2.3 mins
# k =   480 of inf: sim.R = -155.65229797 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  4.83 mins] no improvements in 2.4 mins
# k =   490 of inf: sim.R = -155.65724182 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  4.93 mins] no improvements in 2.5 mins
# k =   500 of inf: sim.R = -155.66864014 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   8] [  5.03 mins] no improvements in 2.6 mins
# k =   510 of inf: sim.R = -155.68838501 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   8] [  5.13 mins] no improvements in 2.7 mins
# k =   520 of inf: sim.R = -155.71073914 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   7] [  5.23 mins] no improvements in 2.8 mins
# k =   530 of inf: sim.R = -155.73167419 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  5.34 mins] no improvements in 2.9 mins
# k =   540 of inf: sim.R = -155.75244141 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  5.44 mins] no improvements in 3.0 mins
# k =   550 of inf: sim.R = -155.76872253 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  5.54 mins] no improvements in 3.1 mins
# k =   560 of inf: sim.R = -155.78817749 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   8] [  5.64 mins] no improvements in 3.2 mins
# k =   570 of inf: sim.R = -155.81120300 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  5.74 mins] no improvements in 3.3 mins
# k =   580 of inf: sim.R = -155.81455994 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   8] [  5.84 mins] no improvements in 3.4 mins
# k =   590 of inf: sim.R = -155.83747864 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  5.94 mins] no improvements in 3.5 mins
# k =   600 of inf: sim.R = -155.85758972 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  6.04 mins] no improvements in 3.6 mins
# k =   610 of inf: sim.R = -155.87512207 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  6.14 mins] no improvements in 3.7 mins
# k =   620 of inf: sim.R = -155.88612366 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  6.24 mins] no improvements in 3.8 mins
# k =   630 of inf: sim.R = -155.90437317 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  6.34 mins] no improvements in 3.9 mins
# k =   640 of inf: sim.R = -155.91812134 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  6.44 mins] no improvements in 4.0 mins
# k =   650 of inf: sim.R = -155.94114685 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  6.54 mins] no improvements in 4.1 mins
# k =   660 of inf: sim.R = -155.96667480 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =  10] [  6.64 mins] no improvements in 4.2 mins
# k =   670 of inf: sim.R = -155.95962524 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  6.74 mins] no improvements in 4.3 mins
# k =   680 of inf: sim.R = -155.98121643 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   7] [  6.84 mins] no improvements in 4.4 mins
# k =   690 of inf: sim.R = -155.99952698 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  6.94 mins] no improvements in 4.5 mins
# k =   700 of inf: sim.R = -156.00149536 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  7.04 mins] no improvements in 4.6 mins
# k =   710 of inf: sim.R = -156.01425171 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  7.15 mins] no improvements in 4.7 mins
# k =   720 of inf: sim.R = -156.02758789 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  7.25 mins] no improvements in 4.8 mins
# k =   730 of inf: sim.R = -156.03262329 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  7.35 mins] no improvements in 4.9 mins
# k =   740 of inf: sim.R = -156.06105042 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  7.45 mins] no improvements in 5.0 mins
# k =   750 of inf: sim.R = -156.06567383 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  7.55 mins] no improvements in 5.1 mins
# k =   760 of inf: sim.R = -156.07624817 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  7.65 mins] no improvements in 5.2 mins
# k =   770 of inf: sim.R = -156.09425354 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  7.75 mins] no improvements in 5.3 mins
# k =   780 of inf: sim.R = -156.09883118 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  7.85 mins] no improvements in 5.4 mins
# k =   790 of inf: sim.R = -156.10897827 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  7.95 mins] no improvements in 5.5 mins
# k =   800 of inf: sim.R = -156.13449097 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  8.05 mins] no improvements in 5.6 mins
# k =   810 of inf: sim.R = -156.13351440 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  8.15 mins] no improvements in 5.7 mins
# k =   820 of inf: sim.R = -156.14950562 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  8.25 mins] no improvements in 5.8 mins
# k =   830 of inf: sim.R = -156.16439819 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  8.35 mins] no improvements in 5.9 mins
# k =   840 of inf: sim.R = -156.16877747 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  8.45 mins] no improvements in 6.0 mins
# k =   850 of inf: sim.R = -156.18064880 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  8.55 mins] no improvements in 6.1 mins
# k =   860 of inf: sim.R = -156.19740295 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  8.65 mins] no improvements in 6.2 mins
# k =   870 of inf: sim.R = -156.20672607 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  8.75 mins] no improvements in 6.3 mins
# k =   880 of inf: sim.R = -156.21182251 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  8.85 mins] no improvements in 6.4 mins
# k =   890 of inf: sim.R = -156.22851562 [best: -70.55063629] [0.7 secs] [value_epochs =  50] [policy_epochs =   6] [  8.95 mins] no improvements in 6.5 mins

# %%
figs, axes = plt.subplots(3, 3, figsize=(16, 9))
axes = axes.flatten()

titles = [
    'Consumption',        # 0
    'House Holdings',     # 1
    'Labor Supply',       # 2
    'Funds',              # 3
    'Bonds',              # 4
    'Equity',             # 5
    'New Debt'            # 6
]

# Map each variable index to a subplot index
var_to_ax = {
    0: 0,  # Consumption
    1: 1,  # House Holdings
    2: 2,  # Labor Supply
    3: 3,  # FundsQ
    4: 4,  # Bonds
    5: 5,  # Equity
    6: 6   # New Debt
}

for model_key, label in model_DL.items():
    if label == 'DeepVPD' or model_key == 'DeepVPD':
        pass
    outcomes = model_DL[model_key].sim.outcomes.cpu().numpy()

    for var_index, ax_index in var_to_ax.items():
        data = outcomes[:, :, var_index]
        mean_series = np.mean(data, axis=1)
        std_series = np.std(data, axis=1)
        p5 = np.percentile(data, 5, axis=1)
        p95 = np.percentile(data, 95, axis=1)

        # Plot mean
        axes[ax_index].plot(mean_series, label=model_key, lw=2)

        # 95% confidence band
        axes[ax_index].fill_between(np.arange(data.shape[0]),
                                    mean_series - 2 * std_series,
                                    mean_series + 2 * std_series,
                                    alpha=0.2)

        # 5th and 95th percentiles
        axes[ax_index].plot(p5, linestyle='--', alpha=0.5)
        axes[ax_index].plot(p95, linestyle='--', alpha=0.5)

# Set titles
for idx, title in enumerate(titles):
    axes[idx].set_title(title)

axes[0].legend()

# Set number formatting
for ax in axes.flat:
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))

# Hide unused axes (positions 7 and 8)
for idx in range(7, 9):
    axes[idx].axis('off')

#figs.suptitle("Outcomes: Impatient Household (β = 0.95, IT = 0.02)", fontsize=16)
figs.suptitle("Outcomes: Patient & Impatient Households", fontsize=16)
figs.tight_layout(rect=[0, 0.03, 1, 0.95])
#figs.savefig("Outcomes_Impatient_Household_TARGET_INFLATION.png", dpi=300)
#figs.savefig("Outcomes_Households_TARGET_INFLATION.png", dpi=300)
plt.show()

# %%
figs, axes = plt.subplots(3, 3, figsize=(16, 9))
axes = axes.flatten()

titles = [
    'Labor Supply (Share)',   # 0
    'Debt Share',             # 1
    'Equity Share',           # 2
    'Bond Share',             # 3
    'House Share'             # 4
]

# Map each variable index to a subplot index
var_to_ax = {
    0: 0,  # 'Labor Supply (Share)'
    1: 1,  #  'Debt Share', 
    2: 2,  # 'Equity Share',
    3: 3,  # 'Bond Share', 
    4: 4,  # 'House Share' 
}

for model_key, label in model_DL.items():
    actions = model_DL[model_key].sim.actions.cpu().numpy()
    
    for var_index, ax_index in var_to_ax.items():
        if var_index >= 2:
            data = actions[:, :, var_index]
            total_asset = np.mean(actions[:, :, 2] + actions[:, :, 3] + actions[:, :, 4], axis=1, keepdims=True)
            mean_series = np.mean(data/ total_asset, axis=1)
            std_series = np.std(data/ total_asset, axis=1)
            p5 = np.percentile(data/ total_asset, 5, axis=1)
            p95 = np.percentile(data/ total_asset, 95, axis=1)
        else:
            data = actions[:, :, var_index]
            mean_series = np.mean(data, axis=1)
            std_series = np.std(data, axis=1)
            p5 = np.percentile(data, 5, axis=1)
            p95 = np.percentile(data, 95, axis=1)
        
          # Plot mean
        axes[ax_index].plot(mean_series, label=model_key, lw=2)

        # 95% confidence band
        axes[ax_index].fill_between(np.arange(data.shape[0]),
                                    mean_series - 2 * std_series,
                                    mean_series + 2 * std_series,
                                    alpha=0.2)

        # 5th and 95th percentiles
        axes[ax_index].plot(p5, linestyle='--', alpha=0.5)
        axes[ax_index].plot(p95, linestyle='--', alpha=0.5)

# Set titles
for idx, title in enumerate(titles):
    axes[idx].set_title(title)

axes[0].legend()

# Set number formatting
for ax in axes.flat:
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))

# Hide unused axes (positions 7 and 8)
for idx in range(5, 9):
    axes[idx].axis('off')

#figs.suptitle("Actions: Impatient Household (β = 0.95), IT = 0.02", fontsize=16)
figs.suptitle("Actions: Patient & Impatient Households", fontsize=16)
figs.tight_layout(rect=[0, 0.03, 1, 0.95])
#figs.savefig("Actions_IMPatient_Household_TARGET_INFLATION.png", dpi=300)
figs.savefig("Actions_Households_TARGET_INFLATION.png", dpi=300)
plt.show()

# %%
figs, axes = plt.subplots(3, 3, figsize=(16, 9))
axes = axes.flatten()

titles = [
    'Wage',                 # 0
    'Money Holdings',       # 1
    'Debt',                 # 2
    'House Price',          # 3
    'Inflation',            # 4
    'Nominal Interest Rate',# 5
    'Return on Equity'      # 6
]

var_to_ax = {
    0: 0,  # Wage
    1: 1,  # Money
    2: 2,  # Debt
    3: 3,  # House Price
    4: 4,  # Inflation
    5: 5,  # Interest Rate
    6: 6   # Return on Equity
}

for model_key, label in model_DL.items():
    states = model_DL[model_key].sim.states.cpu().numpy()

    for var_index, ax_index in var_to_ax.items():
        data = states[:, :, var_index]
        mean_series = np.mean(data, axis=1)
        std_series = np.std(data, axis=1)
        p5 = np.percentile(data, 5, axis=1)
        p95 = np.percentile(data, 95, axis=1)

        # Plot mean
        axes[ax_index].plot(mean_series, label=model_key, lw=2)

        # 95% confidence band
        axes[ax_index].fill_between(np.arange(data.shape[0]),
                                    mean_series - 2 * std_series,
                                    mean_series + 2 * std_series,
                                    alpha=0.2)

        # 5th and 95th percentiles
        axes[ax_index].plot(p5, linestyle='--', alpha=0.5)
        axes[ax_index].plot(p95, linestyle='--', alpha=0.5)

# Add titles
for idx, title in enumerate(titles):
    axes[idx].set_title(title)
    axes[idx].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))

# Add legend once
axes[0].legend()

# Hide last two unused axes
for idx in range(7, 9):
    axes[idx].axis('off')

figs.suptitle("States: Patient & Impatient Households", fontsize=16)
#figs.suptitle("States: Impatient Household (β = 0.95, IT = 0.02)", fontsize=16)
figs.tight_layout(rect=[0, 0.03, 1, 0.95])
figs.savefig("States_Households_TARGET_INFLATION.png", dpi=300)
#figs.savefig("States_Impatient_Household_TARGET_INFLATION.png", dpi=300)
plt.show()

# %%
# Distributional Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Extract simulation outcomes
outcomes_high = model_DL['DeepSimulateBetaHigh'].sim.outcomes.cpu().numpy()
outcomes_low = model_DL['DeepSimulateBetaLow'].sim.outcomes.cpu().numpy()

# Flatten the relevant variables
housing_high = outcomes_high[:, :, 1].flatten()
funds_high = outcomes_high[:, :, 3].flatten()
bonds_high = outcomes_high[:, :, 4].flatten()
equity_high = outcomes_high[:, :, 5].flatten()

housing_low = outcomes_low[:, :, 1].flatten()
funds_low = outcomes_low[:, :, 3].flatten()
bonds_low = outcomes_low[:, :, 4].flatten()
equity_low = outcomes_low[:, :, 5].flatten()

# Plot
fig, axs = plt.subplots(2, 2, figsize=(18, 10))

# --- Funds ---
sns.histplot(funds_high, bins=50, stat='density', kde=False, ax=axs[0, 0], color='red', label=r'$\beta = 0.99$', alpha=0.6)
sns.histplot(funds_low, bins=50, stat='density', kde=False, ax=axs[0, 0], color='blue', label=r'$\beta = 0.95$', alpha=0.4)
axs[0, 0].set_title('Distribution of Funds')
axs[0, 0].set_xlabel('Funds')
axs[0, 0].legend()

# --- Bonds ---
sns.histplot(bonds_high, bins=50, stat='count', kde=False, ax=axs[0, 1], color='red', label=r'$\beta = 0.99$', alpha=0.6)
sns.histplot(bonds_low, bins=50, stat='count', kde=False, ax=axs[0, 1], color='blue', label=r'$\beta = 0.95$', alpha=0.4)
axs[0, 1].set_title('Distribution of Bonds')
axs[0, 1].set_xlabel('Bond Holdings')
axs[0, 1].legend()

# --- Equity ---
sns.histplot(equity_high, bins=50, stat='density', kde=False, ax=axs[1, 0], color='red', label=r'$\beta = 0.99$', alpha=0.6)
sns.histplot(equity_low, bins=50, stat='density', kde=False, ax=axs[1, 0], color='blue', label=r'$\beta = 0.95$', alpha=0.4)
axs[1, 0].set_title('Distribution of Equity')
axs[1, 0].set_xlabel('Equity Holdings')
axs[1, 0].legend()

# --- Housing ---
sns.histplot(housing_high, bins=50, stat='density', kde=False, ax=axs[1, 1], color='red', label=r'$\beta = 0.99$', alpha=0.6)
sns.histplot(housing_low, bins=50, stat='density', kde=False, ax=axs[1, 1], color='blue', label=r'$\beta = 0.95$', alpha=0.4)
axs[1, 1].set_title('Distribution of Housing')
axs[1, 1].set_xlabel('House Holdings')
axs[1, 1].legend()

plt.tight_layout()
fig.savefig("Wealth_Distribution_Households_TARGET_INFLATION.png", dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

states_high = model_DL['DeepSimulateBetaHigh'].sim.states.cpu().numpy()
states_low = model_DL['DeepSimulateBetaLow'].sim.states.cpu().numpy()


# Extract variables from states and outcomes
housing_high = outcomes_high[:, :, 1]
funds_high   = outcomes_high[:, :, 3]
bonds_high   = outcomes_high[:, :, 4]
equity_high  = outcomes_high[:, :, 5]
wage_high    = states_high[:, :, 0]
money_high   = states_high[:, :, 1]
debt_high    = states_high[:, :, 2]

housing_low = outcomes_low[:, :, 1]
funds_low   = outcomes_low[:, :, 3]
bonds_low   = outcomes_low[:, :, 4]
equity_low  = outcomes_low[:, :, 5]
wage_low    = states_low[:, :, 0]
money_low   = states_low[:, :, 1]
debt_low    = states_low[:, :, 2]

# Age group bins (T = 75, starts at 18 → ages 18 to 93)
age_bins = {
    "18–34": np.arange(0, 17),
    "35–49": np.arange(17, 32),
    "50–64": np.arange(32, 47),
    "65–74": np.arange(47, 57),
    "75–84": np.arange(57, 67),
    "85+":   np.arange(67, 75)
}
labels = list(age_bins.keys())

def bin_data(var, bins):
    return [var[bins[label]].flatten() for label in labels]

# Bin each variable
data_high = [
    bin_data(housing_high, age_bins),
    bin_data(funds_high, age_bins),
    bin_data(bonds_high, age_bins),
    bin_data(equity_high, age_bins),
    bin_data(wage_high, age_bins),
    bin_data(money_high, age_bins),
    bin_data(debt_high, age_bins),
]

data_low = [
    bin_data(housing_low, age_bins),
    bin_data(funds_low, age_bins),
    bin_data(bonds_low, age_bins),
    bin_data(equity_low, age_bins),
    bin_data(wage_low, age_bins),
    bin_data(money_low, age_bins),
    bin_data(debt_low, age_bins),
]

titles = ["House Holdings", "Funds", "Bonds", "Equity", "Wages", "Money Holdings", "Debt"]

# Plot
fig, axs = plt.subplots(3, 3, figsize=(18, 12))
axs = axs.flatten()
colors = ["#ff9999", "#66b3ff"]  # High and low beta colors

positions_high = np.arange(len(labels)) - 0.2
positions_low  = np.arange(len(labels)) + 0.2

for i, ax in enumerate(axs[:len(titles)]):
    bp_high = ax.boxplot(data_high[i], positions=positions_high, widths=0.35, patch_artist=True,
                         boxprops=dict(facecolor=colors[0], alpha=0.6), tick_labels=labels)
    bp_low = ax.boxplot(data_low[i], positions=positions_low, widths=0.35, patch_artist=True,
                        boxprops=dict(facecolor=colors[1], alpha=0.6), tick_labels=[""] * len(labels))

    ax.set_title(titles[i])
    ax.set_xticks(np.arange(len(labels)))
    ax.set_xticklabels(labels, rotation=45)
    if i % 3 == 0:
        ax.set_ylabel("Level")
    ax.legend([bp_high["boxes"][0], bp_low["boxes"][0]],
              [r"$\beta = 0.99$", r"$\beta = 0.95$"], loc="upper right")

# Hide empty subplots if fewer than 9
for j in range(len(titles), 9):
    axs[j].axis('off')

plt.tight_layout()
plt.savefig("Boxplot_all_variables_age_groups_Households_TARGET_INFLATION.png", dpi=300)
plt.show()

# %%
### HEAT MAP FOR Portfolio Allocation
# Extract actions (assumes model_key is defined, e.g., 'DeepSimulateBetaHigh')
for model_key, label in model_DL.items():
    actions = model_DL[model_key].sim.actions.cpu().numpy()
    
    # Asset allocations: equity (2), bonds (3), housing (4)
    equity = actions[:, :, 2]
    bonds  = actions[:, :, 3]
    house  = actions[:, :, 4]
    
    # Total assets (avoid division by zero)
    total_asset = equity + bonds + house + 1e-8
    
    # Compute average shares across individuals (axis=1)
    equity_share = np.mean(equity / total_asset, axis=1)
    bond_share   = np.mean(bonds  / total_asset, axis=1)
    house_share  = np.mean(house  / total_asset, axis=1)
    
    # Stack for heatmap (3 x T)
    share_matrix = np.vstack([equity_share, bond_share, house_share])
    
    # Plot
    plt.figure(figsize=(12, 2.5))
    sns.heatmap(share_matrix, cmap='YlGnBu', cbar_kws={'label': 'Portfolio Share (%)'},
                xticklabels=10, yticklabels=['Equity', 'Bonds', 'Housing'])
    
    plt.title(f"Average Portfolio Allocation Over Age ({model_key})")
    plt.xlabel("Age")
    plt.xticks(np.linspace(0, 74, 8), labels=[str(age) for age in range(18, 93, 10)], rotation=0)
    plt.tight_layout()
    plt.show()
